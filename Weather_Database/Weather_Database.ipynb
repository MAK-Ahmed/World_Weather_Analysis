# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | eenhana
# Processing Record 2 of Set 1 | sandwick
# Processing Record 3 of Set 1 | hulyaypole
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | sao gabriel da cachoeira
# Processing Record 9 of Set 1 | klaksvik
# Processing Record 10 of Set 1 | melendugno
# Processing Record 11 of Set 1 | gondar
# Processing Record 12 of Set 1 | murgab
# Processing Record 13 of Set 1 | nortelandia
# Processing Record 14 of Set 1 | yar-sale
# Processing Record 15 of Set 1 | pangnirtung
# Processing Record 16 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | walvis bay
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | maniitsoq
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | angoche
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | dogondoutchi
# Processing Record 30 of Set 1 | olafsvik
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | morshansk
# Processing Record 33 of Set 1 | husavik
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | bandarbeyla
# Processing Record 36 of Set 1 | ilulissat
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | san ramon
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | palmeirais
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 1 | vila franca do campo
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | nova olimpia
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | goregaon
# Processing Record 48 of Set 1 | axim
# Processing Record 49 of Set 1 | athens
# Processing Record 50 of Set 1 | atlantic beach
# Processing Record 1 of Set 2 | paamiut
# Processing Record 2 of Set 2 | laguna
# Processing Record 3 of Set 2 | qasigiannguit
# Processing Record 4 of Set 2 | strenci
# Processing Record 5 of Set 2 | key west
# Processing Record 6 of Set 2 | omboue
# Processing Record 7 of Set 2 | karlovo
# Processing Record 8 of Set 2 | nalut
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | souillac
# Processing Record 11 of Set 2 | nouadhibou
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | umm kaddadah
# Processing Record 15 of Set 2 | santa lucia
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | constitucion
# Processing Record 18 of Set 2 | monrovia
# Processing Record 19 of Set 2 | kristiansund
# Processing Record 20 of Set 2 | virtsu
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | draguignan
# Processing Record 23 of Set 2 | swellendam
# Processing Record 24 of Set 2 | muli
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | belmonte
# Processing Record 27 of Set 2 | gat
# Processing Record 28 of Set 2 | luderitz
# Processing Record 29 of Set 2 | richards bay
# Processing Record 30 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 2 | camopi
# Processing Record 32 of Set 2 | altamira
# Processing Record 33 of Set 2 | bentiu
# Processing Record 34 of Set 2 | cap malheureux
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | saint-pierre
# Processing Record 37 of Set 2 | torbay
# Processing Record 38 of Set 2 | uppsala
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | nanortalik
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | havre-saint-pierre
# Processing Record 43 of Set 2 | tocache
# Processing Record 44 of Set 2 | linhares
# Processing Record 45 of Set 2 | cap-aux-meules
# Processing Record 46 of Set 2 | lagoa
# Processing Record 47 of Set 2 | yarumal
# Processing Record 48 of Set 2 | ivanivka
# Processing Record 49 of Set 2 | skibotn
# Processing Record 50 of Set 2 | san rafael
# Processing Record 1 of Set 3 | bonavista
# Processing Record 2 of Set 3 | la paz
# Processing Record 3 of Set 3 | port-gentil
# Processing Record 4 of Set 3 | blonduos
# City not found. Skipping...
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | mitu
# Processing Record 7 of Set 3 | tabou
# Processing Record 8 of Set 3 | natal
# Processing Record 9 of Set 3 | mabaruma
# Processing Record 10 of Set 3 | coihaique
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | el dorado
# Processing Record 13 of Set 3 | lodja
# Processing Record 14 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 3 | salou
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | clyde river
# Processing Record 18 of Set 3 | nyuksenitsa
# Processing Record 19 of Set 3 | sao jose da coroa grande
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | mgandu
# Processing Record 22 of Set 3 | poroszlo
# Processing Record 23 of Set 3 | copiapo
# Processing Record 24 of Set 3 | adeje
# Processing Record 25 of Set 3 | turukhansk
# Processing Record 26 of Set 3 | dawlatabad
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | ferrol
# Processing Record 29 of Set 3 | mitsamiouli
# Processing Record 30 of Set 3 | vardo
# Processing Record 31 of Set 3 | carutapera
# Processing Record 32 of Set 3 | tessalit
# Processing Record 33 of Set 3 | grand-lahou
# Processing Record 34 of Set 3 | kutum
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3 | puerto suarez
# Processing Record 39 of Set 3 | nantucket
# Processing Record 40 of Set 3 | praia da vitoria
# Processing Record 41 of Set 3 | saint george
# Processing Record 42 of Set 3 | amapa
# Processing Record 43 of Set 3 | dunkwa
# Processing Record 44 of Set 3 | luis correia
# Processing Record 45 of Set 3 | ostersund
# Processing Record 46 of Set 3 | resistencia
# Processing Record 47 of Set 3 | ilhabela
# Processing Record 48 of Set 3 | letlhakane
# Processing Record 49 of Set 3 | mananjary
# Processing Record 50 of Set 3 | touros
# Processing Record 1 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 4 | carupano
# Processing Record 3 of Set 4 | borskoye
# Processing Record 4 of Set 4 | paramonga
# Processing Record 5 of Set 4 | camana
# Processing Record 6 of Set 4 | awbari
# Processing Record 7 of Set 4 | ilebo
# Processing Record 8 of Set 4 | wattegama
# Processing Record 9 of Set 4 | acarau
# Processing Record 10 of Set 4 | barra do bugres
# Processing Record 11 of Set 4 | bahia blanca
# Processing Record 12 of Set 4 | coquimbo
# Processing Record 13 of Set 4 | krasnyy
# Processing Record 14 of Set 4 | barreirinhas
# Processing Record 15 of Set 4 | hamilton
# Processing Record 16 of Set 4 | mahibadhoo
# Processing Record 17 of Set 4 | berlevag
# Processing Record 18 of Set 4 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 19 of Set 4 | raudeberg
# Processing Record 20 of Set 4 | maceio
# Processing Record 21 of Set 4 | rio grande
# Processing Record 22 of Set 4 | jalu
# Processing Record 23 of Set 4 | kokologo
# Processing Record 24 of Set 4 | yialos
# City not found. Skipping...
# Processing Record 25 of Set 4 | dingle
# Processing Record 26 of Set 4 | breytovo
# Processing Record 27 of Set 4 | los llanos de aridane
# Processing Record 28 of Set 4 | rawson
# Processing Record 29 of Set 4 | dunda
# Processing Record 30 of Set 4 | hambantota
# Processing Record 31 of Set 4 | buritis
# Processing Record 32 of Set 4 | viedma
# Processing Record 33 of Set 4 | jalingo
# Processing Record 34 of Set 4 | kedrovyy
# Processing Record 35 of Set 4 | goderich
# Processing Record 36 of Set 4 | mehamn
# Processing Record 37 of Set 4 | carnarvon
# Processing Record 38 of Set 4 | ballina
# Processing Record 39 of Set 4 | cockburn town
# Processing Record 40 of Set 4 | ponta delgada
# Processing Record 41 of Set 4 | bodden town
# Processing Record 42 of Set 4 | asilah
# Processing Record 43 of Set 4 | gap
# Processing Record 44 of Set 4 | abha
# Processing Record 45 of Set 4 | djambala
# Processing Record 46 of Set 4 | surgut
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | segou
# Processing Record 49 of Set 4 | brandfort
# Processing Record 50 of Set 4 | atakpame
# Processing Record 1 of Set 5 | nuuk
# Processing Record 2 of Set 5 | aswan
# Processing Record 3 of Set 5 | bajil
# Processing Record 4 of Set 5 | brae
# Processing Record 5 of Set 5 | ndouci
# City not found. Skipping...
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | necochea
# Processing Record 8 of Set 5 | marsh harbour
# Processing Record 9 of Set 5 | lichtenburg
# Processing Record 10 of Set 5 | gantt
# Processing Record 11 of Set 5 | sasovo
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | hurghada
# Processing Record 14 of Set 5 | ust-ishim
# Processing Record 15 of Set 5 | grand gaube
# Processing Record 16 of Set 5 | ugoofaaru
# Processing Record 17 of Set 5 | pokhara
# Processing Record 18 of Set 5 | falesti
# Processing Record 19 of Set 5 | orcopampa
# Processing Record 20 of Set 5 | taoudenni
# Processing Record 21 of Set 5 | gopalpur
# Processing Record 22 of Set 5 | semnan
# Processing Record 23 of Set 5 | usevya
# Processing Record 24 of Set 5 | harper
# Processing Record 25 of Set 5 | loiza
# Processing Record 26 of Set 5 | coruripe
# Processing Record 27 of Set 5 | tokzar
# City not found. Skipping...
# Processing Record 28 of Set 5 | thinadhoo
# Processing Record 29 of Set 5 | mandali
# Processing Record 30 of Set 5 | pisco
# Processing Record 31 of Set 5 | stamsund
# City not found. Skipping...
# Processing Record 32 of Set 5 | manturovo
# Processing Record 33 of Set 5 | ponta pora
# Processing Record 34 of Set 5 | villa florida
# Processing Record 35 of Set 5 | cabedelo
# Processing Record 36 of Set 5 | glogow
# Processing Record 37 of Set 5 | am timan
# Processing Record 38 of Set 5 | macau
# Processing Record 39 of Set 5 | umm nuwarah
# City not found. Skipping...
# Processing Record 40 of Set 5 | remedios
# Processing Record 41 of Set 5 | sao felix do xingu
# Processing Record 42 of Set 5 | sarh
# Processing Record 43 of Set 5 | urengoy
# Processing Record 44 of Set 5 | adrar
# Processing Record 45 of Set 5 | lasa
# Processing Record 46 of Set 5 | rio gallegos
# Processing Record 47 of Set 5 | pergamino
# Processing Record 48 of Set 5 | longonjo
# Processing Record 49 of Set 5 | danville
# Processing Record 50 of Set 5 | ongole
# Processing Record 1 of Set 6 | fonte boa
# Processing Record 2 of Set 6 | bluefield
# Processing Record 3 of Set 6 | henties bay
# Processing Record 4 of Set 6 | grindavik
# Processing Record 5 of Set 6 | lebu
# Processing Record 6 of Set 6 | chambas
# Processing Record 7 of Set 6 | tefe
# Processing Record 8 of Set 6 | breves
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | bubaque
# Processing Record 11 of Set 6 | krasnoselkup
# Processing Record 12 of Set 6 | addi ugri
# City not found. Skipping...
# Processing Record 13 of Set 6 | cidreira
# Processing Record 14 of Set 6 | yei
# Processing Record 15 of Set 6 | tabas
# Processing Record 16 of Set 6 | meulaboh
# Processing Record 17 of Set 6 | kavaratti
# Processing Record 18 of Set 6 | roald
# Processing Record 19 of Set 6 | sisimiut
# Processing Record 20 of Set 6 | marzuq
# Processing Record 21 of Set 6 | el alto
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | antofagasta
# Processing Record 24 of Set 6 | marawi
# Processing Record 25 of Set 6 | ambanja
# Processing Record 26 of Set 6 | saint-paul
# Processing Record 27 of Set 6 | inhambane
# Processing Record 28 of Set 6 | rurrenabaque
# Processing Record 29 of Set 6 | acari
# Processing Record 30 of Set 6 | manisa
# Processing Record 31 of Set 6 | najran
# Processing Record 32 of Set 6 | goure
# Processing Record 33 of Set 6 | nadvoitsy
# Processing Record 34 of Set 6 | cayenne
# Processing Record 35 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 6 | glyadyanskoye
# Processing Record 37 of Set 6 | nevers
# Processing Record 38 of Set 6 | westport
# Processing Record 39 of Set 6 | les cayes
# Processing Record 40 of Set 6 | khartoum
# Processing Record 41 of Set 6 | makinsk
# Processing Record 42 of Set 6 | anar darreh
# City not found. Skipping...
# Processing Record 43 of Set 6 | bongandanga
# Processing Record 44 of Set 6 | luanda
# Processing Record 45 of Set 6 | saldanha
# Processing Record 46 of Set 6 | padang
# Processing Record 47 of Set 6 | limon
# Processing Record 48 of Set 6 | bahia honda
# Processing Record 49 of Set 6 | boa vista
# Processing Record 50 of Set 6 | nizwa
# Processing Record 1 of Set 7 | quatre cocos
# Processing Record 2 of Set 7 | margate
# Processing Record 3 of Set 7 | caucaia
# Processing Record 4 of Set 7 | severodvinsk
# Processing Record 5 of Set 7 | calabar
# Processing Record 6 of Set 7 | conakry
# Processing Record 7 of Set 7 | savyntsi
# Processing Record 8 of Set 7 | port shepstone
# Processing Record 9 of Set 7 | puerto del rosario
# Processing Record 10 of Set 7 | yahotyn
# Processing Record 11 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 7 | ruyigi
# Processing Record 13 of Set 7 | forestville
# Processing Record 14 of Set 7 | usogorsk
# Processing Record 15 of Set 7 | araouane
# Processing Record 16 of Set 7 | andenes
# Processing Record 17 of Set 7 | santa maria
# Processing Record 18 of Set 7 | barra do corda
# Processing Record 19 of Set 7 | general roca
# Processing Record 20 of Set 7 | islamkot
# Processing Record 21 of Set 7 | la rioja
# Processing Record 22 of Set 7 | huarmey
# Processing Record 23 of Set 7 | saint-louis
# Processing Record 24 of Set 7 | hualmay
# Processing Record 25 of Set 7 | porto velho
# Processing Record 26 of Set 7 | bilma
# Processing Record 27 of Set 7 | korla
# Processing Record 28 of Set 7 | kalmunai
# Processing Record 29 of Set 7 | moussoro
# Processing Record 30 of Set 7 | charlestown
# Processing Record 31 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 7 | maputo
# Processing Record 33 of Set 7 | diego de almagro
# Processing Record 34 of Set 7 | aguia branca
# Processing Record 35 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 7 | diamantino
# Processing Record 37 of Set 7 | bosaso
# Processing Record 38 of Set 7 | antibes
# Processing Record 39 of Set 7 | ust-koksa
# Processing Record 40 of Set 7 | nicoya
# Processing Record 41 of Set 7 | xacmaz
# Processing Record 42 of Set 7 | caravelas
# Processing Record 43 of Set 7 | dubreka
# Processing Record 44 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 45 of Set 7 | manica
# Processing Record 46 of Set 7 | sur
# Processing Record 47 of Set 7 | manoel urbano
# Processing Record 48 of Set 7 | kisangani
# Processing Record 49 of Set 7 | vizinga
# Processing Record 50 of Set 7 | puerto ayora
# Processing Record 1 of Set 8 | villa maria
# Processing Record 2 of Set 8 | kontagora
# Processing Record 3 of Set 8 | caluquembe
# Processing Record 4 of Set 8 | lixourion
# Processing Record 5 of Set 8 | rafaela
# Processing Record 6 of Set 8 | dipkarpaz
# City not found. Skipping...
# Processing Record 7 of Set 8 | sept-iles
# Processing Record 8 of Set 8 | eucaliptus
# Processing Record 9 of Set 8 | belize
# Processing Record 10 of Set 8 | chagoda
# Processing Record 11 of Set 8 | skoghall
# Processing Record 12 of Set 8 | ahvaz
# Processing Record 13 of Set 8 | paarl
# Processing Record 14 of Set 8 | chapais
# Processing Record 15 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 8 | sumbe
# Processing Record 17 of Set 8 | dudinka
# Processing Record 18 of Set 8 | qaqortoq
# Processing Record 19 of Set 8 | palora
# Processing Record 20 of Set 8 | port hawkesbury
# Processing Record 21 of Set 8 | saint-augustin
# Processing Record 22 of Set 8 | igrim
# Processing Record 23 of Set 8 | kirillov
# Processing Record 24 of Set 8 | mopti
# Processing Record 25 of Set 8 | whitewater
# Processing Record 26 of Set 8 | sovetskaya
# Processing Record 27 of Set 8 | aksarka
# Processing Record 28 of Set 8 | faya
# Processing Record 29 of Set 8 | wad madani
# Processing Record 30 of Set 8 | lehututu
# Processing Record 31 of Set 8 | san cristobal
# Processing Record 32 of Set 8 | caraballeda
# Processing Record 33 of Set 8 | panama city
# Processing Record 34 of Set 8 | new albany
# Processing Record 35 of Set 8 | shahr-e babak
# Processing Record 36 of Set 8 | mazyr
# Processing Record 37 of Set 8 | covington
# Processing Record 38 of Set 8 | ormara
# Processing Record 39 of Set 8 | leshukonskoye
# Processing Record 40 of Set 8 | stornoway
# Processing Record 41 of Set 8 | comodoro rivadavia
# Processing Record 42 of Set 8 | joshimath
# Processing Record 43 of Set 8 | fougamou
# Processing Record 44 of Set 8 | parana
# Processing Record 45 of Set 8 | masumbwe
# Processing Record 46 of Set 8 | puerto colombia
# Processing Record 47 of Set 8 | kupino
# Processing Record 48 of Set 8 | kindu
# Processing Record 49 of Set 8 | terenos
# Processing Record 50 of Set 8 | stryn
# Processing Record 1 of Set 9 | sioux lookout
# Processing Record 2 of Set 9 | hommersak
# Processing Record 3 of Set 9 | arcachon
# Processing Record 4 of Set 9 | lopandino
# Processing Record 5 of Set 9 | sao filipe
# Processing Record 6 of Set 9 | kanigiri
# Processing Record 7 of Set 9 | gaoual
# Processing Record 8 of Set 9 | salalah
# Processing Record 9 of Set 9 | bayir
# Processing Record 10 of Set 9 | teguldet
# Processing Record 11 of Set 9 | sistranda
# Processing Record 12 of Set 9 | joao pinheiro
# Processing Record 13 of Set 9 | itarema
# Processing Record 14 of Set 9 | sechura
# Processing Record 15 of Set 9 | polazna
# Processing Record 16 of Set 9 | palmas de monte alto
# Processing Record 17 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 9 | bhilwara
# Processing Record 19 of Set 9 | saint-georges
# Processing Record 20 of Set 9 | vryburg
# Processing Record 21 of Set 9 | jimma
# Processing Record 22 of Set 9 | doha
# Processing Record 23 of Set 9 | garowe
# Processing Record 24 of Set 9 | ladario
# Processing Record 25 of Set 9 | itaguai
# Processing Record 26 of Set 9 | saint-joseph
# Processing Record 27 of Set 9 | aguimes
# Processing Record 28 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 29 of Set 9 | oksovskiy
# Processing Record 30 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 31 of Set 9 | voyvozh
# Processing Record 32 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 9 | luangwa
# Processing Record 34 of Set 9 | pelym
# Processing Record 35 of Set 9 | remanso
# Processing Record 36 of Set 9 | guanajay
# Processing Record 37 of Set 9 | isoka
# Processing Record 38 of Set 9 | reserva
# Processing Record 39 of Set 9 | orbetello
# Processing Record 40 of Set 9 | borgo san dalmazzo
# Processing Record 41 of Set 9 | darnah
# Processing Record 42 of Set 9 | codrington
# Processing Record 43 of Set 9 | uray
# Processing Record 44 of Set 9 | sindor
# Processing Record 45 of Set 9 | ancud
# Processing Record 46 of Set 9 | zaragoza
# Processing Record 47 of Set 9 | carndonagh
# Processing Record 48 of Set 9 | umreth
# Processing Record 49 of Set 9 | iguape
# Processing Record 50 of Set 9 | madras
# Processing Record 1 of Set 10 | saint-francois
# Processing Record 2 of Set 10 | geraldton
# Processing Record 3 of Set 10 | gonc
# Processing Record 4 of Set 10 | puri
# Processing Record 5 of Set 10 | ileza
# Processing Record 6 of Set 10 | abu samrah
# Processing Record 7 of Set 10 | lyaskelya
# Processing Record 8 of Set 10 | trelew
# Processing Record 9 of Set 10 | oranjemund
# Processing Record 10 of Set 10 | dalvik
# Processing Record 11 of Set 10 | cepelare
# Processing Record 12 of Set 10 | tabory
# Processing Record 13 of Set 10 | manyana
# Processing Record 14 of Set 10 | daura
# Processing Record 15 of Set 10 | pemba
# Processing Record 16 of Set 10 | tarko-sale
# Processing Record 17 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 10 | taltal
# Processing Record 19 of Set 10 | vorukh
# Processing Record 20 of Set 10 | eirunepe
# Processing Record 21 of Set 10 | nueva loja
# Processing Record 22 of Set 10 | vila velha
# Processing Record 23 of Set 10 | beloha
# Processing Record 24 of Set 10 | uusikaupunki
# Processing Record 25 of Set 10 | asfi
# Processing Record 26 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 27 of Set 10 | keti bandar
# Processing Record 28 of Set 10 | vestmannaeyjar
# Processing Record 29 of Set 10 | barahona
# Processing Record 30 of Set 10 | mpanda
# Processing Record 31 of Set 10 | santa luzia
# Processing Record 32 of Set 10 | surt
# Processing Record 33 of Set 10 | ipixuna
# Processing Record 34 of Set 10 | maragogi
# Processing Record 35 of Set 10 | havelock
# Processing Record 36 of Set 10 | watsa
# Processing Record 37 of Set 10 | caldono
# Processing Record 38 of Set 10 | shache
# Processing Record 39 of Set 10 | sundargarh
# Processing Record 40 of Set 10 | itaituba
# Processing Record 41 of Set 10 | sonqor
# Processing Record 42 of Set 10 | yarim
# Processing Record 43 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 44 of Set 10 | macapa
# Processing Record 45 of Set 10 | allapalli
# Processing Record 46 of Set 10 | varnavino
# Processing Record 47 of Set 10 | voi
# Processing Record 48 of Set 10 | campo verde
# Processing Record 49 of Set 10 | bay city
# Processing Record 50 of Set 10 | kashi
# Processing Record 1 of Set 11 | yabelo
# Processing Record 2 of Set 11 | hofn
# Processing Record 3 of Set 11 | gamba
# Processing Record 4 of Set 11 | aripuana
# Processing Record 5 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 6 of Set 11 | shebalino
# Processing Record 7 of Set 11 | puerto leguizamo
# Processing Record 8 of Set 11 | siniscola
# Processing Record 9 of Set 11 | paita
# Processing Record 10 of Set 11 | thiruvananthapuram
# Processing Record 11 of Set 11 | gazojak
# Processing Record 12 of Set 11 | freeport
# Processing Record 13 of Set 11 | safaga
# Processing Record 14 of Set 11 | hamirpur
# Processing Record 15 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 16 of Set 11 | ambilobe
# Processing Record 17 of Set 11 | yenagoa
# Processing Record 18 of Set 11 | kismayo
# Processing Record 19 of Set 11 | vallenar
# Processing Record 20 of Set 11 | solenzo
# Processing Record 21 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 22 of Set 11 | port washington
# Processing Record 23 of Set 11 | ailigandi
# Processing Record 24 of Set 11 | olavarria
# Processing Record 25 of Set 11 | sorland
# Processing Record 26 of Set 11 | harlingen
# Processing Record 27 of Set 11 | la romana
# Processing Record 28 of Set 11 | vadinsk
# Processing Record 29 of Set 11 | inirida
# Processing Record 30 of Set 11 | porosozero
# Processing Record 31 of Set 11 | fulacunda
# City not found. Skipping...
# Processing Record 32 of Set 11 | san ramon de la nueva oran
# Processing Record 33 of Set 11 | awjilah
# Processing Record 34 of Set 11 | lieksa
# Processing Record 35 of Set 11 | shibarghan
# City not found. Skipping...
# Processing Record 36 of Set 11 | kargopol
# Processing Record 37 of Set 11 | lobito
# Processing Record 38 of Set 11 | mahanoro
# Processing Record 39 of Set 11 | turayf
# Processing Record 40 of Set 11 | roverud
# Processing Record 41 of Set 11 | rosario
# Processing Record 42 of Set 11 | shieli
# Processing Record 43 of Set 11 | usinsk
# Processing Record 44 of Set 11 | chany
# Processing Record 45 of Set 11 | revda
# Processing Record 46 of Set 11 | tatarsk
# Processing Record 47 of Set 11 | bombay
# Processing Record 48 of Set 11 | supia
# Processing Record 49 of Set 11 | cuamba
# Processing Record 50 of Set 11 | benguela
# Processing Record 1 of Set 12 | tourlaville
# Processing Record 2 of Set 12 | bjerkvik
# Processing Record 3 of Set 12 | zanjan
# Processing Record 4 of Set 12 | chardara
# Processing Record 5 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 6 of Set 12 | istanbul
# Processing Record 7 of Set 12 | metehara
# City not found. Skipping...
# Processing Record 8 of Set 12 | samarkand
# Processing Record 9 of Set 12 | suure-jaani
# Processing Record 10 of Set 12 | hobyo
# Processing Record 11 of Set 12 | marfino
# Processing Record 12 of Set 12 | urrao
# Processing Record 13 of Set 12 | sabha
# Processing Record 14 of Set 12 | la brea
# Processing Record 15 of Set 12 | americus
# Processing Record 16 of Set 12 | kaduqli
# Processing Record 17 of Set 12 | birin
# Processing Record 18 of Set 12 | jumla
# Processing Record 19 of Set 12 | bonthe
# Processing Record 20 of Set 12 | maarianhamina
# Processing Record 21 of Set 12 | barentu
# Processing Record 22 of Set 12 | shu
# Processing Record 23 of Set 12 | naryan-mar
# Processing Record 24 of Set 12 | arrifes
# Processing Record 25 of Set 12 | plettenberg bay
# Processing Record 26 of Set 12 | rudbar
# Processing Record 27 of Set 12 | gainesville
# Processing Record 28 of Set 12 | beyneu
# Processing Record 29 of Set 12 | remontnoye
# Processing Record 30 of Set 12 | lethem
# Processing Record 31 of Set 12 | gualeguay
# Processing Record 32 of Set 12 | iraucuba
# Processing Record 33 of Set 12 | umred
# Processing Record 34 of Set 12 | arnold
# Processing Record 35 of Set 12 | krasnoborsk
# Processing Record 36 of Set 12 | ulagan
# Processing Record 37 of Set 12 | hukuntsi
# Processing Record 38 of Set 12 | etah
# Processing Record 39 of Set 12 | chalmette
# Processing Record 40 of Set 12 | aksu
# Processing Record 41 of Set 12 | wazzan
# City not found. Skipping...
# Processing Record 42 of Set 12 | spring hill
# Processing Record 43 of Set 12 | eskisehir
# Processing Record 44 of Set 12 | banda aceh
# Processing Record 45 of Set 12 | valparaiso
# Processing Record 46 of Set 12 | barcarena
# Processing Record 47 of Set 12 | barreirinha
# Processing Record 48 of Set 12 | millau
# Processing Record 49 of Set 12 | goksun
# Processing Record 50 of Set 12 | zwedru
# Processing Record 1 of Set 13 | arlit
# Processing Record 2 of Set 13 | mandera
# Processing Record 3 of Set 13 | lucea
# Processing Record 4 of Set 13 | guntakal
# Processing Record 5 of Set 13 | olkhovatka
# Processing Record 6 of Set 13 | werda
# Processing Record 7 of Set 13 | kuminskiy
# Processing Record 8 of Set 13 | nador
# Processing Record 9 of Set 13 | itapevi
# Processing Record 10 of Set 13 | riviere-au-renard
# Processing Record 11 of Set 13 | barkhan
# Processing Record 12 of Set 13 | mazagao
# Processing Record 13 of Set 13 | andijon
# Processing Record 14 of Set 13 | de aar
# Processing Record 15 of Set 13 | san matias
# Processing Record 16 of Set 13 | mehran
# Processing Record 17 of Set 13 | iquique
# Processing Record 18 of Set 13 | chateauroux
# Processing Record 19 of Set 13 | soyo
# Processing Record 20 of Set 13 | baherden
# Processing Record 21 of Set 13 | sinnamary
# Processing Record 22 of Set 13 | antalaha
# Processing Record 23 of Set 13 | kulhudhuffushi
# Processing Record 24 of Set 13 | kautokeino
# Processing Record 25 of Set 13 | korem
# Processing Record 26 of Set 13 | praia
# Processing Record 27 of Set 13 | wolmaranstad
# City not found. Skipping...
# Processing Record 28 of Set 13 | farafangana
# Processing Record 29 of Set 13 | port antonio
# Processing Record 30 of Set 13 | gwadar
# Processing Record 31 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 13 | mala vyska
# Processing Record 33 of Set 13 | marsa matruh
# Processing Record 34 of Set 13 | louis trichardt
# Processing Record 35 of Set 13 | sao desiderio
# Processing Record 36 of Set 13 | agadez
# Processing Record 37 of Set 13 | sakakah
# Processing Record 38 of Set 13 | jacareacanga
# Processing Record 39 of Set 13 | saint anthony
# Processing Record 40 of Set 13 | batticaloa
# Processing Record 41 of Set 13 | karibib
# Processing Record 42 of Set 13 | zhanaozen
# Processing Record 43 of Set 13 | lazdijai
# Processing Record 44 of Set 13 | beruwala
# Processing Record 45 of Set 13 | talcahuano
# Processing Record 46 of Set 13 | kalush
# Processing Record 47 of Set 13 | thaba-tseka
# Processing Record 48 of Set 13 | sendafa
# Processing Record 49 of Set 13 | saurimo
# Processing Record 50 of Set 13 | cochrane
# Processing Record 1 of Set 14 | monte cristi
# City not found. Skipping...
# Processing Record 2 of Set 14 | esmeraldas
# Processing Record 3 of Set 14 | letterkenny
# Processing Record 4 of Set 14 | rocha
# Processing Record 5 of Set 14 | tsumeb
# Processing Record 6 of Set 14 | kaka
# Processing Record 7 of Set 14 | massakory
# Processing Record 8 of Set 14 | lakeside
# Processing Record 9 of Set 14 | oriximina
# Processing Record 10 of Set 14 | pila
# Processing Record 11 of Set 14 | fatezh
# Processing Record 12 of Set 14 | thasra
# Processing Record 13 of Set 14 | alakurtti
# Processing Record 14 of Set 14 | raduzhnyy
# Processing Record 15 of Set 14 | koundara
# Processing Record 16 of Set 14 | avila
# Processing Record 17 of Set 14 | ascoli piceno
# Processing Record 18 of Set 14 | mangrol
# Processing Record 19 of Set 14 | gojra
# Processing Record 20 of Set 14 | upington
# Processing Record 21 of Set 14 | imbituba
# Processing Record 22 of Set 14 | iquitos
# Processing Record 23 of Set 14 | morant bay
# Processing Record 24 of Set 14 | weligama
# Processing Record 25 of Set 14 | chicama
# Processing Record 26 of Set 14 | keta
# Processing Record 27 of Set 14 | biga
# Processing Record 28 of Set 14 | moose factory
# Processing Record 29 of Set 14 | bobo dioulasso
# Processing Record 30 of Set 14 | floro
# Processing Record 31 of Set 14 | araxa
# Processing Record 32 of Set 14 | havoysund
# Processing Record 33 of Set 14 | timra
# Processing Record 34 of Set 14 | tysmenytsya
# Processing Record 35 of Set 14 | khash
# Processing Record 36 of Set 14 | shushtar
# Processing Record 37 of Set 14 | niteroi
# Processing Record 38 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 39 of Set 14 | camacha
# Processing Record 40 of Set 14 | kinsale
# Processing Record 41 of Set 14 | pitimbu
# Processing Record 42 of Set 14 | yelkhovka
# Processing Record 43 of Set 14 | bathsheba
# Processing Record 44 of Set 14 | guacui
# Processing Record 45 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of Set 14 | guajara
# Processing Record 47 of Set 14 | razole
# Processing Record 48 of Set 14 | riyadh
# Processing Record 49 of Set 14 | ostrovnoy
# Processing Record 50 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 1 of Set 15 | bariadi
# Processing Record 2 of Set 15 | mao
# Processing Record 3 of Set 15 | coro
# Processing Record 4 of Set 15 | yeehaw junction
# City not found. Skipping...
# Processing Record 5 of Set 15 | mogadishu
# Processing Record 6 of Set 15 | dhidhdhoo
# Processing Record 7 of Set 15 | semey
# Processing Record 8 of Set 15 | abu kamal
# Processing Record 9 of Set 15 | abdanan
# Processing Record 10 of Set 15 | kungsbacka
# Processing Record 11 of Set 15 | oksfjord
# Processing Record 12 of Set 15 | lindsay
# Processing Record 13 of Set 15 | kingisepp
# Processing Record 14 of Set 15 | mizdah
# Processing Record 15 of Set 15 | runkel
# Processing Record 16 of Set 15 | russi
# Processing Record 17 of Set 15 | tukrah
# Processing Record 18 of Set 15 | zabid
# Processing Record 19 of Set 15 | balashov
# Processing Record 20 of Set 15 | sehithwa
# Processing Record 21 of Set 15 | muros
# Processing Record 22 of Set 15 | bagado
# Processing Record 23 of Set 15 | gornouralskiy
# City not found. Skipping...
# Processing Record 24 of Set 15 | xapuri
# Processing Record 25 of Set 15 | cocobeach
# Processing Record 26 of Set 15 | afua
# Processing Record 27 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 28 of Set 15 | odweyne
# Processing Record 29 of Set 15 | pajan
# Processing Record 30 of Set 15 | ritchie
# Processing Record 31 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 15 | muisne
# Processing Record 33 of Set 15 | isla mujeres
# Processing Record 34 of Set 15 | pangody
# Processing Record 35 of Set 15 | salta
# Processing Record 36 of Set 15 | chiredzi
# Processing Record 37 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 15 | opuwo
# Processing Record 39 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 15 | bud
# Processing Record 41 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 15 | senigallia
# Processing Record 43 of Set 15 | purace
# City not found. Skipping...
# Processing Record 44 of Set 15 | kidal
# Processing Record 45 of Set 15 | chingirlau
# Processing Record 46 of Set 15 | contai
# Processing Record 47 of Set 15 | annau
# Processing Record 48 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 49 of Set 15 | muzhi
# Processing Record 50 of Set 15 | vila do maio
# Processing Record 1 of Set 16 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 16 | skjervoy
# Processing Record 3 of Set 16 | marystown
# Processing Record 4 of Set 16 | pedernales
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 695

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                        City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0                   Eenhana -17.4667  16.3333     71.24        19          71
# 1                  Sandwick  60.0000  -1.2500     53.42        87          20
# 2                Hulyaypole  47.6653  36.2578     51.89        68           6
# 3              Punta Arenas -53.1500 -70.9167     42.91        70          75
# 4               Port Alfred -33.5906  26.8910     58.17        87         100
# 5                 Upernavik  72.7868 -56.1549     25.16        89         100
# 6                 Cape Town -33.9258  18.4232     60.39        72          40
# 7  Sao Gabriel Da Cachoeira  -0.1303 -67.0892     78.84        72          17
# 8                  Klaksvik  62.2266  -6.5890     45.52        76          50
# 9                Melendugno  40.2747  18.3368     65.05        94           0
#
#    Wind Speed Country Current Description
# 0        3.56      NA       broken clouds
# 1       20.71      GB          light rain
# 2        6.78      UA           clear sky
# 3       14.97      CL       broken clouds
# 4        4.00      ZA     overcast clouds
# 5        0.78      GL          light snow
# 6        3.44      ZA    scattered clouds
# 7        2.57      BR          few clouds
# 8       14.36      FO    scattered clouds
# 9        8.05      IT           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_columns]

# Display sample data
city_data_df.head(10)
# Out:
#                        City Country      Lat      Lng  Max Temp  Humidity  \
# 0                   Eenhana      NA -17.4667  16.3333     71.24        19
# 1                  Sandwick      GB  60.0000  -1.2500     53.42        87
# 2                Hulyaypole      UA  47.6653  36.2578     51.89        68
# 3              Punta Arenas      CL -53.1500 -70.9167     42.91        70
# 4               Port Alfred      ZA -33.5906  26.8910     58.17        87
# 5                 Upernavik      GL  72.7868 -56.1549     25.16        89
# 6                 Cape Town      ZA -33.9258  18.4232     60.39        72
# 7  Sao Gabriel Da Cachoeira      BR  -0.1303 -67.0892     78.84        72
# 8                  Klaksvik      FO  62.2266  -6.5890     45.52        76
# 9                Melendugno      IT  40.2747  18.3368     65.05        94
#
#    Cloudiness  Wind Speed Current Description
# 0          71        3.56       broken clouds
# 1          20       20.71          light rain
# 2           6        6.78           clear sky
# 3          75       14.97       broken clouds
# 4         100        4.00     overcast clouds
# 5         100        0.78          light snow
# 6          40        3.44    scattered clouds
# 7          17        2.57          few clouds
# 8          50       14.36    scattered clouds
# 9           0        8.05           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_data = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_data, index_label="City_ID")
